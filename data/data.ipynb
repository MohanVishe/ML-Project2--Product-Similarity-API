# %%
import openai
from dotenv import load_dotenv
import pandas as pd

# %%
openai.api_key="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"

# %%
pd.DataFrame(openai.Model.list()["data"])
# Out:
#                              id object     created         owned_by
# 0             gpt-3.5-turbo-16k  model  1683758102  openai-internal
# 1                     whisper-1  model  1677532384  openai-internal
# 2                   davinci-002  model  1692634301           system
# 3                      dall-e-2  model  1698798177           system
# 4                 tts-1-hd-1106  model  1699053533           system
# 5                      tts-1-hd  model  1699046015           system
# 6        text-embedding-3-large  model  1705953180           system
# 7            gpt-3.5-turbo-0125  model  1706048358           system
# 8                 gpt-3.5-turbo  model  1677610602           openai
# 9   gpt-3.5-turbo-instruct-0914  model  1694122472           system
# 10           gpt-3.5-turbo-0301  model  1677649963           openai
# 11           gpt-3.5-turbo-0613  model  1686587434           openai
# 12                        tts-1  model  1681940951  openai-internal
# ...

# %%
#  chat completion api

openai.Completion.create(
    model="whisper-1",
    prompt="create product data as dataframe where the columns contain productname,detail description ,price ,category and review with 1000 rows"
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 #  chat completion api
# ----> 3 openai.Completion.create(
#       4     model="whisper-1",
#       5     prompt="create product data as dataframe where the columns contain productname,detail description ,price ,category and review with 1000 rows"
#       6 )
#
# File d:\Data Science\Projects\ML-Project2--Product-Similarity-API\MLp2Env\Lib\site-packages\openai\api_resources\completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# ...
